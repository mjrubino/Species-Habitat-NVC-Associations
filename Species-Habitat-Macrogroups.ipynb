# %% [markdown]
# # Table of contents
# 1. [Purpose](#purpose)
# 2. [Inputs](#inputs)
#     * [2.1 SQL Databases](#subinput1)
# 3. [Outputs](#outputs)
# 4. [Constraints](#constraints)
# 5. [Dependencies](#dependencies)
#     * [5.1 Code Language](#codelanguage)
#       * [5.1.1 package requirements](#packagerequirements)
#
# 6. [Code](#code)
# 7. [Tests](#tests)
# 8. [Provenance](#provenance)
# 9. [Citations](#citations)
# ---
#
# # GAP Species Habitat Associations and the National Vegetation Classification (NVC) System Hierarchy
# <br/>
#
# ## Purpose <a name="purpose"></a>
# The U.S. Geological Survey Gap Analysis Project (GAP) created habitat maps for 1590 terrestrial vertebrate species throughout the conterminous US (CONUS), including 219 sub-species. Each species was associated with one or more land cover types represented in the National GAP Land Cover Map (McKerrow et al. 2018, Gergely et al. 2019). The USGS GAP Land Cover Map used vegetation classes based on NatureServe’s Ecological Systems Classification (Comer et al. 2003) and land cover classes described in the National Land Cover Dataset (Homer et al. 2007). These data described vegetation communities at a level of thematic detail useful for ascribing habitat types for species. A crosswalk of that map legend with the nested hierarchy of the US National Vegetation Classification (NVC) permits the assessment of species habitat extents throughtout a broadening thematic vegetation classification.
#
# This notebook specifically outlines using the crosswalk of species habitat associations in the GAP land cover map with NVC macrogroups for linking USDA Forest Inventory and Analysis (FIA) plot level forest composition and structure data.
#
# ## Inputs <a name="inputs"></a>
# The code in this notebook is a first step in combining GAP species habitat association information with FIA plot level data wherein forest structure and composition are tied to NVC macrogroup classes. Since the GAP habitat maps were developed using deductive methods (McKerrow et al. 2018, Gergely et al. 2019) which include landscape attributes other than land cover, it was necessary to identify species whose associations include forest and no other ancillary data such as distance to water or elevation limits.
#
# Data compiled by code in this notebook are assembled in a wildlife habitat relationship database (WHRdb). The WHRdb was queried to compile a list of species associated with at least one forested land cover type (referred to as <b>map units</b> in WHRdb tables) and no ancillary landscape attributes. Modeling parameters were assembled for each species by seasonality - summer (breeding for migratory birds), winter, and year-round (habitat utilized during both summer and winter). Additionally, modeling regions were used to stratify the CONUS into six regions (Northwest, Southwest, Great Plains, Upper Midwest, Southeast, and Northeast). These regions allowed for efficient processing of the species distribution models on smaller, ecologically homogenous extents. Therefore, species habitat associations may occur in multiple seasons and/or across multiple regions. A species model code was developed to maintain unique season/region combinations.
#
# * **U.S. Geological Survey Gap Analysis Project (GAP) Wildlife Habitat Relationship Database** <a name="subinput1"></a>
# Information about access to a given instance of this database is pending. The database is described here: https://www.sciencebase.gov/catalog/item/527d0a83e4b0850ea0518326.
#
# Additionally, this code utilizes an SQL server database that was assembled by intersecting numerous spatial data layers including the PAD-US, species habitat maps, boundary layers such as states, counties, LCCs, ecoregions, etc.
#
# * **U.S. Geological Survey Gap Analysis Project (GAP) Analytical Database** <a name="subinput1"></a>
# These analyses utilize the GAP Analytic database developed by Linda Schueck, Anne Davidson, and Leah Dunn at Boise State University. Information about access to a given instance of this database is pending. The database is described here: https://www.sciencebase.gov/catalog/item/5b736251e4b0f5d5787c61df.
#
# At the time this workflow was developed, both databases were available on a local server. Hence, all code references a local instance of these databases. This code is only replicable given access to a local instance of these databases.
#
# This analysis relies on three major datasets within the analytic database including:
# 1. The detailed land cover dataset: GAP/LANDFIRE National Terrestrial Ecosystems 2011: National Inventory of Vegetation and Land Use  (https://www.sciencebase.gov/catalog/item/5810cd6fe4b0f497e7975237)
# 2. The U.S. National Vegetation Classification Ver 2.0 (http://usnvc.org/explore-classification/)
# 3. A crosswalk between Ecological Systems and the USNVC Types (Embedded in the Attribute file for the National Terrestrials Ecosystems data https://www.sciencebase.gov/catalog/item/5810cd6fe4b0f497e7975237.
#
# ## Outputs <a name="outputs"></a>
# A table and output CSV file with data on species map unit and NVC macrogroup associations organized by season and modeling region. The following columns are included in the table:
# * <b>ScientificName</b> - species scientific name
# * <b>CommonName</b> - species common name
# * <b>SC</b> - species 6-letter code
# * <b>SMC</b> - species 9-charcter model code
# * <b>MUCode</b> - land cover map unit 4-digit code
# * <b>MUName</b> - land cover map unit name
# * <b>Season</b> - species model season
# * <b>Region</b> - species model region
# * <b>Macrogroup</b> - NVC macrogroup name
#
#
# ## Constraints <a name="constraints"></a>
# The Land Cover data attempts to map as accurately as possible the fine vegetative details of the nation’s vegetation. However, there are some limitations to the data that users should keep in mind. The data set uses a 30 meter pixel cell and in most areas a minimum mapping unit of 0.4 ha (1 acre). This means that small patches of vegetation can be missed in the modeling process.  The USNVC is a dynamic content standard, reflecting the state of the science at any point in time; therefore this analysis represents the conservation assessment based on the types that were named and described in the 2017 release of the classification.
#
# ## Dependencies <a name="dependencies"></a>
# These analyses are currently reliant on a local instance of the GAP Wildlife Habitat Relationship database (GAP WHRdb) and the GAP Analytical Database (GAP analytic db).
#
# Code execution dependencies
#
# * **Code Language** <a name="codelanguage"></a>
# This code is written in Python 3.x. Earlier versions may be compatible given slight alterations in syntax and package components.
#   * **Python package requirements** <a name="packagerequirements"></a>
#   The required packages for proper code execution inlclude:
#     - Pandas version 0.2x or above
#     - pyodbc version 4.x or above
#
#
# ## Tests <a name="tests"></a>
# In developing this code the results were compared against a dataset generated through an independent spatial analysis.
#
#
# ## Provenance <a name="provenance"></a>

# %% [markdown]
# ## Code <a name="code"></a>

# %% [markdown]
# #### Import required Python packages

# %%
import pyodbc
import pandas as pd
import pandas.io.sql as psql
#%matplotlib notebook

# %% [markdown]
# #### Accessing the local SQL server instance of the GAP Analytic database

# %%
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#            ++++ Directory Locations ++++
workDir = 'C:/Data/USGS Analyses/NVC-Analyses/Scripts/'


#############################################################################################
################################### LOCAL FUNCTIONS #########################################
#############################################################################################


## --------------Cursor and Database Connections--------------------

def ConnectToDB(connectionStr):
    '''
    (str) -> cursor, connection

    Provides a cursor within and a connection to the database

    Argument:
    connectionStr -- The SQL Server compatible connection string
        for connecting to a database
    '''
    try:
        con = pyodbc.connect(connectionStr)
    except:
        connectionStr = connectionStr.replace('11.0', '10.0')
        con = pyodbc.connect(connectionStr)

    return con.cursor(), con

## ----------------Database Connection----------------------

def DBConnection(dbname):
    '''
    Returns a cursor and connection within the GAP analytic database.
    '''
    # Database connection parameters
    dbstr = """DRIVER=SQL Server Native Client 11.0;
                    SERVER=CHUCK\SQL2014;
                    UID=;
                    PWD=;
                    TRUSTED_CONNECTION=Yes;
                    DATABASE={0};"""
    dbConStr = dbstr.format(dbname)

    return ConnectToDB(dbConStr)

#############################################################################################
#############################################################################################
#############################################################################################

# %%
## Connect to the Analytic Database
print("+"*45)
print("Connecting to Database ....")
cur, conn = DBConnection('GAP_AnalyticDB')
# Out:
# +++++++++++++++++++++++++++++++++++++++++++++
# Connecting to Database ....

# %% [markdown]
# #### Generating an SQL string to pass to a pandas dataframe

# %%
# Make an SQL that pulls out NVC macrogroups from the Analytic db
sqlGA = """SELECT
            level3,
            nvc_macro AS Macrogroup
        FROM
            GAP_AnalyticDB.dbo.gap_landfire
        WHERE level3 > 0"""

# %% [markdown]
# #### Passing the SQL and getting a pandas dataframe

# %%
# Make a dataframe of the macrogroups with the 4-digit code
print("Creating Dataframe of NVC Macrogroups from Gap Analytic Datbase ....")
dfMacro = psql.read_sql(sqlGA, conn)
# Out:
# Creating Dataframe of NVC Macrogroups from Gap Analytic Datbase ....

# %%
dfMacro
# Out:
#      level3                                         Macrogroup
# 0      9238                                    Caribbean Swamp
# 1      9702                                    Caribbean Swamp
# 2      9305                                    Caribbean Swamp
# 3      9236              Western Atlantic & Caribbean Mangrove
# 4      4132               Caribbean Coastal Lowland Dry Forest
# 5      4135               Caribbean Coastal Lowland Dry Forest
# 6      4134               Caribbean Coastal Lowland Dry Forest
# 7      4145                             Longleaf Pine Woodland
# 8      4505                             Longleaf Pine Woodland
# 9      4506                             Longleaf Pine Woodland
# 10     4536                             Longleaf Pine Woodland
# 11     5602                             Longleaf Pine Woodland
# 12     4508                             Longleaf Pine Woodland
# 13     4509                             Longleaf Pine Woodland
# 14     4503                             Longleaf Pine Woodland
# 15     4502                             Longleaf Pine Woodland
# 16     4321                             Longleaf Pine Woodland
# 17     4210  Southeastern Coastal Plain Evergreen Oak - Mix...
# 18     4212  Southeastern Coastal Plain Evergreen Oak - Mix...
# 19     4136  Southeastern Coastal Plain Evergreen Oak - Mix...
# 20     4102              Southern Mesic Mixed Broadleaf Forest
# 21     4150  Southeastern Coastal Plain Evergreen Oak - Mix...
# 22     4129              Southern Mesic Mixed Broadleaf Forest
# 23     4209              Southern Mesic Mixed Broadleaf Forest
# 24     4153  Southeastern Coastal Plain Evergreen Oak - Mix...
# 25     4130  Southeastern Coastal Plain Evergreen Oak - Mix...
# 26     4146  Southeastern Coastal Plain Evergreen Oak - Mix...
# 27     4137  Southeastern Coastal Plain Evergreen Oak - Mix...
# 28     4204              Southern Mesic Mixed Broadleaf Forest
# 29     4541  Southern & South-Central Oak - Hickory - Pine ...
# ..      ...                                                ...
# 542    3502                                             Barren
# 543    1401                           Woody Horticultural Crop
# 544    1402                 Herbaceous Agricultural Vegetation
# 545    1403                           Pasture & Hay Field Crop
# 546    8404               Introduced & Semi Natural Vegetation
# 547    8407               Introduced & Semi Natural Vegetation
# 548    8408               Introduced & Semi Natural Vegetation
# 549    8402               Introduced & Semi Natural Vegetation
# 550    8406               Introduced & Semi Natural Vegetation
# 551    8401               Introduced & Semi Natural Vegetation
# 552    8501                     Recently Disturbed or Modified
# 553    8101                     Recently Disturbed or Modified
# 554    8108                     Recently Disturbed or Modified
# 555    8107                     Recently Disturbed or Modified
# 556    8106                     Recently Disturbed or Modified
# 557    8301                     Recently Disturbed or Modified
# 558    8303                     Recently Disturbed or Modified
# 559    8304                     Recently Disturbed or Modified
# 560    8302                     Recently Disturbed or Modified
# 561    8103                     Recently Disturbed or Modified
# 562    8102                     Recently Disturbed or Modified
# 563    8502                     Recently Disturbed or Modified
# 564    2104                                         Open Water
# 565    2103                                         Open Water
# 566    2102                                         Open Water
# 567    1301         Quarries, Mines, Gravel Pits and Oil Wells
# 568    1201                                  Developed & Urban
# 569    1202                                  Developed & Urban
# 570    1203                                  Developed & Urban
# 571    1204                                  Developed & Urban
#
# [572 rows x 2 columns]

# %% [markdown]
# #### Delete the cursor and connection to the Analytic database to reuse variables for connection to WHR database

# %%
# Delete the previous db connection variables and reset them for
# connecting to the WHR database
del cur, conn
print('Connecting to Gap WHR Database ....')
cur, conn = DBConnection('GapVert_48_2001')
# Out:
# Connecting to Gap WHR Database ....

# %% [markdown]
# #### Pull out species map unit associations from the WHR for species associated with at least one forested type and no ancillary constraints

# %%
# Make an SQL that gets data for species who have at least one forested map unit
# and have NO ancillary data constraints
sqlWHR = """WITH
NonAncillary AS
(SELECT	strSpeciesModelCode,
		ysnHandModel,
		ysnHydroFW,
		ysnHydroOW,
		ysnHydroWV,
		ysnHydroSprings,
		strSalinity,
		strStreamVel,
		intFlowAccMin,
		intFlowAccMax,
		strEdgeType,
		intEdgeEcoWidth,
		strUseForInt,
		strForIntBuffer,
		cbxContPatch,
		cbxNonCPatch,
		intContPatchSize,
		intContPatchBuffIn,
		intContPatchBuffFrom,
		intNonCPatchPerc,
		intNonCPatchArea,
		intPercentCanopy,
		intAuxBuff,
		strAvoid,
		ysnUrbanExclude,
		ysnUrbanInclude,
		intElevMin,
		intElevMax,
		intSlopeMin,
		intSlopeMax
FROM tblModelAncillary
WHERE	strSpeciesModelCode Not Like '%0' AND
		ysnHandModel = 0 AND
		ysnHydroFW = 0 AND 
		ysnHydroOW = 0 AND 
		ysnHydroWV = 0 AND 
		ysnHydroSprings = 0 AND 
		strSalinity Is Null AND 
		strStreamVel Is Null AND 
		intFlowAccMin Is Null AND 
		intFlowAccMax Is Null AND 
		strEdgeType Is Null AND 
		intEdgeEcoWidth Is Null AND 
		strUseForInt Is Null AND 
		strForIntBuffer Is Null AND 
		cbxContPatch = 0 AND 
		cbxNonCPatch = 0 AND 
		intContPatchSize Is Null AND 
		intContPatchBuffIn Is Null AND 
		intContPatchBuffFrom Is Null AND 
		intNonCPatchPerc Is Null AND 
		intNonCPatchArea Is Null AND 
		intPercentCanopy Is Null AND 
		intAuxBuff Is Null AND 
		strAvoid Is Null AND 
		ysnUrbanExclude = 0 AND 
		ysnUrbanInclude = 0 AND 
		intElevMin Is Null AND 
		intElevMax Is Null AND 
		intSlopeMin Is Null AND 
		intSlopeMax Is Null
),



ForestSelected AS 
(SELECT
		tblMapUnitDesc.intLSGapMapCode,
		tblMapUnitDesc.strLSGapName,
		tblMapUnitDesc.intForest,
		tblSppMapUnitPres.strSpeciesModelCode,
		tblSppMapUnitPres.ysnPres,
		tblModelInfo.ysnIncludeSubModel
FROM 
		tblMapUnitDesc FULL JOIN tblSppMapUnitPres 
		ON tblMapUnitDesc.intLSGapMapCode = tblSppMapUnitPres.intLSGapMapCode
		INNER JOIN tblModelInfo 
		ON tblSppMapUnitPres.strSpeciesModelCode = tblModelInfo.strSpeciesModelCode
WHERE 
		tblMapUnitDesc.intForest = 1 AND 
		tblSppMapUnitPres.ysnPres = 1 AND 
		tblSppMapUnitPres.strSpeciesModelCode Not Like '%m_' AND
		tblModelInfo.ysnIncludeSubModel = 1),


Taxa AS
(SELECT strUC, strSciName, strComName
FROM tblTaxa)

SELECT 	Taxa.strSciName AS ScientificName,
		Taxa.strComName AS CommonName,
		Taxa.strUC AS SC,
		NonAncillary.strSpeciesModelCode AS SMC,
		ForestSelected.intLSGapMapCode AS MUCode,
		ForestSelected.strLSGapName AS MUName,
		CASE 
			WHEN 
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 8, 1)='y'
			  THEN 'year-round'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 8, 1)='s'
			  THEN 'summer'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 8, 1)='w'
			  THEN 'winter'
		END AS Season,
		
		CASE 
			WHEN 
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='1'
			  THEN 'Northwest'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='2'
			  THEN 'Upper Midwest'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='3'
			  THEN 'Northeast'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='4'
			  THEN 'Southwest'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='5'
			  THEN 'Great Plains'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='6'
			  THEN 'Southeast'
		END AS Region

FROM NonAncillary INNER JOIN ForestSelected ON NonAncillary.strSpeciesModelCode = ForestSelected.strSpeciesModelCode
				  INNER JOIN Taxa ON SUBSTRING(NonAncillary.strSpeciesModelCode, 1, 6) = Taxa.strUC"""

# %% [markdown]
# #### Make a dataframe using the above criteria

# %%
# Make a dataframe of the forest/non-ancillary species map unit associations
dfSppMUs = psql.read_sql(sqlWHR, conn)

# %%
dfSppMUs
# Out:
#                    ScientificName                 CommonName      SC  \
# 0           Ophisaurus compressus        Island Glass Lizard  rIGLIx
# 1         Aspidoscelis sexlineata       Six-lined Racerunner  rSLRAx
# 2              Cemophora coccinea               Scarletsnake  rSCARx
# 3             Diadophis punctatus          Ring-necked Snake  rRNSNx
# 4             Anolis carolinensis                Green Anole  rGRANx
# 5             Coluber constrictor       North American Racer  rNARAx
# 6              Ophisaurus mimicus         Mimic Glass Lizard  rMGLIx
# 7                Micrurus fulvius       Harlequin Coralsnake  rHACOx
# 8            Sceloporus undulatus       Eastern Fence Lizard  rEFLIx
# 9                 Storeria dekayi         Dekay's Brownsnake  rDEBRx
# 10            Plestiodon laticeps         Broad-headed Skink  rBHSKx
# 11             Dendroica dominica    Yellow-throated Warbler  bYTWAx
# 12             Dendroica dominica    Yellow-throated Warbler  bYTWAx
# 13             Dendroica coronata      Yellow-rumped Warbler  bYRWAx
# 14         Zonotrichia albicollis     White-throated Sparrow  bWTSPx
# 15           Archilochus colubris  Ruby-throated Hummingbird  bRTHUx
# 16           Archilochus colubris  Ruby-throated Hummingbird  bRTHUx
# 17     Melanerpes erythrocephalus      Red-headed Woodpecker  bRHWOx
# 18              Regulus calendula       Ruby-crowned Kinglet  bRCKIx
# 19             Dryocopus pileatus        Pileated Woodpecker  bPIWOx
# 20            Melospiza lincolnii          Lincoln's Sparrow  bLISPx
# 21              Catharus guttatus              Hermit Thrush  bHETHx
# 22                Regulus satrapa     Golden-crowned Kinglet  bGCKIx
# 23              Corvus ossifragus                  Fish Crow  bFICRx
# 24        Pipilo erythrophthalmus             Eastern Towhee  bEATOx
# 25        Pipilo erythrophthalmus             Eastern Towhee  bEATOx
# 26                Contopus virens         Eastern Wood-pewee  bEAWPx
# 27              Corvus ossifragus                  Fish Crow  bFICRx
# 28        Pipilo erythrophthalmus             Eastern Towhee  bEATOx
# 29        Pipilo erythrophthalmus             Eastern Towhee  bEATOx
# ...                           ...                        ...     ...
# 16556      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16557      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16558      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16559      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16560      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16561      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16562      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16563      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16564      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16565      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16566      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16567      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16568      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16569      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16570      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16571      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16572      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16573      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16574      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16575      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16576      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16577      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16578      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16579      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16580      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16581      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16582      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16583      Peromyscus maniculatus   North American Deermouse  mNADEx
# 16584         Synaptomys borealis       Northern Bog Lemming  mNBLEx
# 16585         Synaptomys borealis       Northern Bog Lemming  mNBLEx
#
#              SMC  MUCode                                             MUName  \
# 0      rIGLIx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 1      rSLRAx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 2      rSCARx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 3      rRNSNx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 4      rGRANx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 5      rNARAx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 6      rMGLIx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 7      rHACOx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 8      rEFLIx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 9      rDEBRx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 10     rBHSKx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 11     bYTWAx-s5    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 12     bYTWAx-w5    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 13     bYRWAx-w6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 14     bWTSPx-w6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 15     bRTHUx-s6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 16     bRTHUx-w6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 17     bRHWOx-w6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 18     bRCKIx-w6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 19     bPIWOx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 20     bLISPx-w6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 21     bHETHx-w6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 22     bGCKIx-w6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 23     bFICRx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 24     bEATOx-w5    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 25     bEATOx-w6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 26     bEAWPx-s6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 27     bFICRx-y2    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 28     bEATOx-s5    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 29     bEATOx-s6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# ...          ...     ...                                                ...
# 16556  mNADEx-y3    4323  Laurentian-Acadian Northern Pine-(Oak) Forest ...
# 16557  mNADEx-y3    4327  Laurentian-Acadian Pine-Hemlock-Hardwood Fores...
# 16558  mNADEx-y3    4329  Southern Piedmont Dry Oak-(Pine) Forest       ...
# 16559  mNADEx-y3    4330  Central Appalachian Oak and Pine Forest       ...
# 16560  mNADEx-y3    4331  Appalachian Hemlock-Hardwood Forest           ...
# 16561  mNADEx-y3    4333  Acadian Low-Elevation Spruce-Fir-Hardwood Fore...
# 16562  mNADEx-y3    4334  Southern Ridge and Valley Dry Calcareous Fores...
# 16563  mNADEx-y3    4401  Southern and Central Appalachian Cove Forest  ...
# 16564  mNADEx-y3    4402  South-Central Interior Mesophytic Forest      ...
# 16565  mNADEx-y3    4403  Atlantic Coastal Plain Mesic Hardwood and Mixe...
# 16566  mNADEx-y3    4538  Southern Appalachian Low Mountain Pine Forest ...
# 16567  mNADEx-y3    4551  Acadian-Appalachian Montane Spruce-Fir Forest ...
# 16568  mNADEx-y3    4612  Central and Southern Appalachian Spruce-Fir Fo...
# 16569  mNADEx-y3    8202               Evergreen Plantation or Managed Pine
# 16570  mNADEx-y3    8203                            Managed Tree Plantation
# 16571  mNADEx-y3    8401               Introduced Upland Vegetation - Treed
# 16572  mNADEx-y3    9801  Atlantic Coastal Plain Blackwater Stream Flood...
# 16573  mNADEx-y3    9802  Central Appalachian Floodplain - Forest Modifi...
# 16574  mNADEx-y3    9803  Central Appalachian Riparian - Forest Modifier...
# 16575  mNADEx-y3    9805  South-Central Interior Large Floodplain - Fore...
# 16576  mNADEx-y3    9806  Southern Piedmont Large Floodplain Forest - Fo...
# 16577  mNADEx-y3    9818  Central Interior and Appalachian Floodplain Sy...
# 16578  mNADEx-y3    9819  Central Interior and Appalachian Riparian Syst...
# 16579  mNADEx-y3    9827  Mississippi River Riparian Forest             ...
# 16580  mNADEx-y3    9841  Southern Piedmont Small Floodplain and Riparia...
# 16581  mNADEx-y3    9842  Atlantic Coastal Plain Small Brownwater River ...
# 16582  mNADEx-y3    9843  Atlantic Coastal Plain Small Blackwater River ...
# 16583  mNADEx-y3    9850  South-Central Interior Small Stream and Ripari...
# 16584  mNBLEx-y3    4333  Acadian Low-Elevation Spruce-Fir-Hardwood Fore...
# 16585  mNBLEx-y3    4551  Acadian-Appalachian Montane Spruce-Fir Forest ...
#
#            Season         Region
# 0      year-round      Southeast
# 1      year-round      Southeast
# 2      year-round      Southeast
# 3      year-round      Southeast
# 4      year-round      Southeast
# 5      year-round      Southeast
# 6      year-round      Southeast
# 7      year-round      Southeast
# 8      year-round      Southeast
# 9      year-round      Southeast
# 10     year-round      Southeast
# 11         summer   Great Plains
# 12         winter   Great Plains
# 13         winter      Southeast
# 14         winter      Southeast
# 15         summer      Southeast
# 16         winter      Southeast
# 17         winter      Southeast
# 18         winter      Southeast
# 19     year-round      Southeast
# 20         winter      Southeast
# 21         winter      Southeast
# 22         winter      Southeast
# 23     year-round      Southeast
# 24         winter   Great Plains
# 25         winter      Southeast
# 26         summer      Southeast
# 27     year-round  Upper Midwest
# 28         summer   Great Plains
# 29         summer      Southeast
# ...           ...            ...
# 16556  year-round      Northeast
# 16557  year-round      Northeast
# 16558  year-round      Northeast
# 16559  year-round      Northeast
# 16560  year-round      Northeast
# 16561  year-round      Northeast
# 16562  year-round      Northeast
# 16563  year-round      Northeast
# 16564  year-round      Northeast
# 16565  year-round      Northeast
# 16566  year-round      Northeast
# 16567  year-round      Northeast
# 16568  year-round      Northeast
# 16569  year-round      Northeast
# 16570  year-round      Northeast
# 16571  year-round      Northeast
# 16572  year-round      Northeast
# 16573  year-round      Northeast
# 16574  year-round      Northeast
# 16575  year-round      Northeast
# 16576  year-round      Northeast
# 16577  year-round      Northeast
# 16578  year-round      Northeast
# 16579  year-round      Northeast
# 16580  year-round      Northeast
# 16581  year-round      Northeast
# 16582  year-round      Northeast
# 16583  year-round      Northeast
# 16584  year-round      Northeast
# 16585  year-round      Northeast
#
# [16586 rows x 8 columns]

# %% [markdown]
# ### Merge the two dataframes derived from the Analytic and WHR databases to show map units and their associated macrogroups

# %%
# Merge the dataframes from the WHR and Analytc dbs using the columns
# that have map unit 4-digit codes: MUCode and level3 respectively
dfSppMUs_Macro = pd.merge(left=dfSppMUs, right=dfMacro, how='inner',
                      left_on='MUCode', right_on='level3')

# %%
dfSppMUs_Macro=dfSppMUs_Macro.sort_values(by=['SMC'])
dfSppMUs_Macro
# Out:
#                  ScientificName                     CommonName      SC  \
# 9761           Aneides lugubris            Arboreal Salamander  aARSAx
# 9762           Aneides lugubris            Arboreal Salamander  aARSAx
# 11708      Plethodon caddoensis      Caddo Mountain Salamander  aCMSAx
# 14309      Plethodon caddoensis      Caddo Mountain Salamander  aCMSAx
# 15363      Plethodon caddoensis      Caddo Mountain Salamander  aCMSAx
# 7408         Plethodon kentucki  Cumberland Plateau Salamander  aCPSAx
# 7618         Plethodon kentucki  Cumberland Plateau Salamander  aCPSAx
# 1850    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 6870    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 5582    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 5231    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 3918    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4893    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 9461    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 3412    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 5076    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 5648    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 6285    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 7668    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 6982    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 12498   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 9540    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4202    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4325    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 9725    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4966    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4828    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 3683    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4107    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 9490    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# ...                         ...                            ...     ...
# 13004  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 14966  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 4277   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 14703  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 9378   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 14478  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 5341   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 10583  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 10413  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 10671  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 11116  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 10952  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 52     Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 7072   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 10812  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 10876  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 16029  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 7130   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 6091   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 11053  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 8515   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 7309   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 10517  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 15961  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 9988       Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 7010       Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 9860       Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 5106       Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 13316     Gonatodes albogularis            Yellow-headed Gecko  rYHGEx
# 2609      Gonatodes albogularis            Yellow-headed Gecko  rYHGEx
#
#              SMC  MUCode                                             MUName  \
# 9761   aARSAx-y1    4317  Mediterranean California Lower Montane Black O...
# 9762   aARSAx-y4    4317  Mediterranean California Lower Montane Black O...
# 11708  aCMSAx-y6    4207  Ozark-Ouachita Mesic Hardwood Forest          ...
# 14309  aCMSAx-y6    4122  Ouachita Montane Oak Forest                   ...
# 15363  aCMSAx-y6    4115  Ozark-Ouachita Dry-Mesic Oak Forest           ...
# 7408   aCPSAx-y6    4402  South-Central Interior Mesophytic Forest      ...
# 7618   aCPSAx-y6    4401  Southern and Central Appalachian Cove Forest  ...
# 1850   aCSLSx-y1    9811  North Pacific Lowland Riparian Forest and Shru...
# 6870   aCSLSx-y1    4522  North Pacific Maritime Dry-Mesic Douglas-fir-W...
# 5582   aCSLSx-y1    4547  North Pacific Dry-Mesic Silver Fir-Western Hem...
# 5231   aCSLSx-y1    4601  California Coastal Redwood Forest             ...
# 3918   aCSLSx-y1    8202               Evergreen Plantation or Managed Pine
# 4893   aCSLSx-y1    4606  North Pacific Maritime Mesic-Wet Douglas-fir-W...
# 9461   aCSLSx-y1    4320  Mediterranean California Mixed Evergreen Fores...
# 3412   aCSLSx-y1    8401               Introduced Upland Vegetation - Treed
# 5076   aCSLSx-y1    4603  Mediterranean California Mesic Mixed Conifer F...
# 5648   aCSLSx-y1    4545  California Coastal Closed-Cone Conifer Forest ...
# 6285   aCSLSx-y1    4533  Sierra Nevada Subalpine Lodgepole Pine Forest ...
# 7668   aCSLSx-y1    4338  North Pacific Lowland Mixed Hardwood-Conifer F...
# 6982   aCSLSx-y1    4519  Mediterranean California Dry-Mesic Mixed Conif...
# 12498  aCSLSx-y1    4148  North Pacific Broadleaf Landslide Forest and S...
# 9540   aCSLSx-y1    4319  North Pacific Dry Douglas-fir-(Madrone) Forest...
# 4202   aCSLSx-y1    8106  Harvested Forest - Northwestern Conifer Regene...
# 4325   aCSLSx-y1    4613  North Pacific Hypermaritime Western Red-cedar-...
# 9725   aCSLSx-y1    4317  Mediterranean California Lower Montane Black O...
# 4966   aCSLSx-y1    4604  North Pacific Hypermaritime Sitka Spruce Fores...
# 4828   aCSLSx-y1    4607  North Pacific Mesic Western Hemlock-Silver Fir...
# 3683   aCSLSx-y1    8203                            Managed Tree Plantation
# 4107   aCSLSx-y1    8201                               Deciduous Plantation
# 9490   aCSLSx-y4    4320  Mediterranean California Mixed Evergreen Fores...
# ...          ...     ...                                                ...
# 13004  rYBKIx-y5    4136  Central and South Texas Coastal Fringe Forest ...
# 14966  rYBKIx-y5    4118  Crosstimbers Oak Forest and Woodland          ...
# 4277   rYBKIx-y5    7602  Llano Uplift Acidic Forest, Woodland and Glade...
# 14703  rYBKIx-y5    4120  North-Central Interior Dry-Mesic Oak Forest an...
# 9378   rYBKIx-y5    4321  West Gulf Coastal Plain Upland Longleaf Pine F...
# 14478  rYBKIx-y5    4121  North-Central Interior Dry Oak Forest and Wood...
# 5341   rYBKIx-y5    4553  Atlantic Coastal Plain Fall-line Sandhills Lon...
# 10583  rYBKIx-y6    4309  East Gulf Coastal Plain Interior Shortleaf Pin...
# 10413  rYBKIx-y6    4311  Southern Piedmont Dry Oak-Heath Forest - Mixed...
# 10671  rYBKIx-y6    4308  Southern Ridge and Valley Dry Calcareous Fores...
# 11116  rYBKIx-y6    4303  East Gulf Coastal Plain Black Belt Calcareous ...
# 10952  rYBKIx-y6    4305  Southern Piedmont Dry Oak-(Pine) Forest - Lobl...
# 52     rYBKIx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 7072   rYBKIx-y6    4507  East Gulf Coastal Plain Interior Upland Longle...
# 10812  rYBKIx-y6    4307  Allegheny-Cumberland Dry Oak Forest and Woodla...
# 10876  rYBKIx-y6    4306  East Gulf Coastal Plain Northern Dry Upland Ha...
# 16029  rYBKIx-y6    4105  East Gulf Coastal Plain Northern Loess Plain O...
# 7130   rYBKIx-y6    4504  Atlantic Coastal Plain Fall-Line Sandhills Lon...
# 6091   rYBKIx-y6    4538  Southern Appalachian Low Mountain Pine Forest ...
# 11053  rYBKIx-y6    4304  Northeastern Interior Dry Oak Forest - Virgini...
# 8515   rYBKIx-y6    4330  Central Appalachian Oak and Pine Forest       ...
# 7309   rYBKIx-y6    4403  Atlantic Coastal Plain Mesic Hardwood and Mixe...
# 10517  rYBKIx-y6    4310  Southern Piedmont Dry Oak-(Pine) Forest - Mixe...
# 15961  rYBKIx-y6    4106  Northeastern Interior Dry Oak Forest - Mixed M...
# 9988   rYBSLx-y4    4315  Madrean Pine-Oak Forest and Woodland          ...
# 7010   rYBSLx-y4    4519  Mediterranean California Dry-Mesic Mixed Conif...
# 9860   rYBSLx-y4    4316  Madrean Upper Montane Conifer-Oak Forest and W...
# 5106   rYBSLx-y4    4603  Mediterranean California Mesic Mixed Conifer F...
# 13316  rYHGEx-y6    4132  South Florida Hardwood Hammock                ...
# 2609   rYHGEx-y6    9702  South Florida Cypress Dome                    ...
#
#            Season        Region  level3  \
# 9761   year-round     Northwest    4317
# 9762   year-round     Southwest    4317
# 11708  year-round     Southeast    4207
# 14309  year-round     Southeast    4122
# 15363  year-round     Southeast    4115
# 7408   year-round     Southeast    4402
# 7618   year-round     Southeast    4401
# 1850   year-round     Northwest    9811
# 6870   year-round     Northwest    4522
# 5582   year-round     Northwest    4547
# 5231   year-round     Northwest    4601
# 3918   year-round     Northwest    8202
# 4893   year-round     Northwest    4606
# 9461   year-round     Northwest    4320
# 3412   year-round     Northwest    8401
# 5076   year-round     Northwest    4603
# 5648   year-round     Northwest    4545
# 6285   year-round     Northwest    4533
# 7668   year-round     Northwest    4338
# 6982   year-round     Northwest    4519
# 12498  year-round     Northwest    4148
# 9540   year-round     Northwest    4319
# 4202   year-round     Northwest    8106
# 4325   year-round     Northwest    4613
# 9725   year-round     Northwest    4317
# 4966   year-round     Northwest    4604
# 4828   year-round     Northwest    4607
# 3683   year-round     Northwest    8203
# 4107   year-round     Northwest    8201
# 9490   year-round     Southwest    4320
# ...           ...           ...     ...
# 13004  year-round  Great Plains    4136
# 14966  year-round  Great Plains    4118
# 4277   year-round  Great Plains    7602
# 14703  year-round  Great Plains    4120
# 9378   year-round  Great Plains    4321
# 14478  year-round  Great Plains    4121
# 5341   year-round  Great Plains    4553
# 10583  year-round     Southeast    4309
# 10413  year-round     Southeast    4311
# 10671  year-round     Southeast    4308
# 11116  year-round     Southeast    4303
# 10952  year-round     Southeast    4305
# 52     year-round     Southeast    9911
# 7072   year-round     Southeast    4507
# 10812  year-round     Southeast    4307
# 10876  year-round     Southeast    4306
# 16029  year-round     Southeast    4105
# 7130   year-round     Southeast    4504
# 6091   year-round     Southeast    4538
# 11053  year-round     Southeast    4304
# 8515   year-round     Southeast    4330
# 7309   year-round     Southeast    4403
# 10517  year-round     Southeast    4310
# 15961  year-round     Southeast    4106
# 9988   year-round     Southwest    4315
# 7010   year-round     Southwest    4519
# 9860   year-round     Southwest    4316
# 5106   year-round     Southwest    4603
# 13316  year-round     Southeast    4132
# 2609   year-round     Southeast    9702
#
#                                               Macrogroup
# 9761                       Californian Forest & Woodland
# 9762                       Californian Forest & Woodland
# 11708                       Central Midwest Mesic Forest
# 14309  Southern & South-Central Oak - Hickory - Pine ...
# 15363  Southern & South-Central Oak - Hickory - Pine ...
# 7408   Appalachian-Central Interior-Northeastern Mesi...
# 7618   Appalachian-Central Interior-Northeastern Mesi...
# 1850   Vancouverian Lowland Marsh, Wet Meadow & Shrub...
# 6870               Vancouverian Lowland & Montane Forest
# 5582               Vancouverian Lowland & Montane Forest
# 5231               Vancouverian Lowland & Montane Forest
# 3918          Southeastern North American Ruderal Forest
# 4893               Vancouverian Lowland & Montane Forest
# 9461                       Californian Forest & Woodland
# 3412                Introduced & Semi Natural Vegetation
# 5076       Southern Vancouverian Montane-Foothill Forest
# 5648                       Californian Forest & Woodland
# 6285                       Vancouverian Subalpine Forest
# 7668               Vancouverian Lowland & Montane Forest
# 6982       Southern Vancouverian Montane-Foothill Forest
# 12498              Vancouverian Lowland & Montane Forest
# 9540           Southern Vancouverian Dry Foothill Forest
# 4202                      Recently Disturbed or Modified
# 4325               Vancouverian Lowland & Montane Forest
# 9725                       Californian Forest & Woodland
# 4966               Vancouverian Lowland & Montane Forest
# 4828               Vancouverian Lowland & Montane Forest
# 3683               Eastern North American Ruderal Forest
# 4107          Southeastern North American Ruderal Forest
# 9490                       Californian Forest & Woodland
# ...                                                  ...
# 13004  Southeastern Coastal Plain Evergreen Oak - Mix...
# 14966  Southern & South-Central Oak - Hickory - Pine ...
# 4277                   Edwards Plateau Forest & Woodland
# 14703     Central Midwest Oak Forest, Woodland & Savanna
# 9378                              Longleaf Pine Woodland
# 14478     Central Midwest Oak Forest, Woodland & Savanna
# 5341                              Longleaf Pine Woodland
# 10583  Southern & South-Central Oak - Hickory - Pine ...
# 10413  Southern & South-Central Oak - Hickory - Pine ...
# 10671  Appalachian-Northeastern Oak - Hardwood - Pine...
# 11116  Southern & South-Central Oak - Hickory - Pine ...
# 10952         Southeastern North American Ruderal Forest
# 52        Southern Coastal Plain Basin Swamp & Flatwoods
# 7072          Southeastern North American Ruderal Forest
# 10812  Appalachian-Northeastern Oak - Hardwood - Pine...
# 10876         Southeastern North American Ruderal Forest
# 16029  Southern & South-Central Oak - Hickory - Pine ...
# 7130          Southeastern North American Ruderal Forest
# 6091   Southern & South-Central Oak - Hickory - Pine ...
# 11053  Appalachian-Northeastern Oak - Hardwood - Pine...
# 8515   Appalachian-Northeastern Oak - Hardwood - Pine...
# 7309               Southern Mesic Mixed Broadleaf Forest
# 10517  Southern & South-Central Oak - Hickory - Pine ...
# 15961  Appalachian-Northeastern Oak - Hardwood - Pine...
# 9988                   Madrean Montane Forest & Woodland
# 7010       Southern Vancouverian Montane-Foothill Forest
# 9860                   Madrean Montane Forest & Woodland
# 5106       Southern Vancouverian Montane-Foothill Forest
# 13316               Caribbean Coastal Lowland Dry Forest
# 2609                                     Caribbean Swamp
#
# [16433 rows x 10 columns]

# %% [markdown]
# ### Export the data to a CSV file

# %%
# Export to CSV file
dfSppMUs_Macro.to_csv(workDir + "Species-Habitat-Macrogroups.csv")

# %% [markdown]
# ## Citations <a name="citations"></a>
# Comer, P.J., Faber-Langendoen D., Evans, R., Gawler, S.C., Josse, C., Kittel, G., Menard, S., Pyne, M., Reid, M., Schulz, K., Snow, K., and Teague, J., 2003, Ecological systems of the United States—A working classification of U.S. terrestrial systems: Arlington, NatureServe. [Also available at http://www.natureserve.org/biodiversity-science/publications/ecological-systems-united-states.
#
# Gergely, K.J., Boykin, K.G., McKerrow, A.J., Rubino, M.J., Tarr, N.M., and Williams, S.G., 2019, Gap Analysis Project (GAP) terrestrial vertebrate species richness maps for the conterminous U.S.: U.S. Geological Survey Scientific Investigations Report 2019–5034, 99 p., https://doi.org/10.3133/sir20195034.
#
# Homer, C.J., Dewitz, J., Fry, M., Coan, N., Hossain, C., Larson, N., Herold, A., McKerrow, J.N., VanDriel, J.N., and Wickham, J., 2007, Completion of the 2001 National Land Cover Database for the Conterminous United States: Photogrammetric Engineering and Remote Sensing, v. 73, issue 4, p. 337–341, accessed July 30, 2018, at https://www.researchgate.net/profile/Collin_Homer/publication/237239863_Completion_of_the_2001_National_Land_Cover_Database_for_the_Conterminous_United_States/links/0046352ab204d93a3e000000.pdf.
#
# McKerrow, A.J., Tarr, N.M., Rubino, M.J., and Williams, S.G., 2018, Patterns of species richness hotspots and estimates of their protection are sensitive to spatial resolution: Diversity and Distributions, v. 24, issue 10, p. 1464–1477, accessed July 30, 2018, at https://doi.org/10.1111/ddi.12779.
#
# U.S. Geological Survey Gap Analysis Program, 20160513, GAP/LANDFIRE National Terrestrial Ecosystems 2011: U.S. Geological Survey, https://doi.org/10.5066/F7ZS2TM0.
#
# USNVC [United States National Vegetation Classification]. 2017. United States National Vegetation Classification Database, V2.01. Federal Geographic Data Committee, Vegetation Subcommittee, Washington DC. [usnvc.org/explore-classification/] (accessed 30 March 2017).

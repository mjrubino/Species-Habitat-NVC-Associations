# %% [markdown]
# # Table of contents
# 1. [Purpose](#purpose)
# 2. [Inputs](#inputs)
#     * [2.1 SQL Databases](#subinput1)
# 3. [Outputs](#outputs)
# 4. [Constraints](#constraints)
# 5. [Dependencies](#dependencies)
#     * [5.1 Code Language](#codelanguage)
#       * [5.1.1 package requirements](#packagerequirements)
#
# 6. [Code](#code)
# 7. [Tests](#tests)
# 8. [Provenance](#provenance)
# 9. [Citations](#citations)
# ---
#
# # GAP Species Habitat Associations and the National Vegetation Classification (NVC) System Hierarchy
# <br/>
#
# ## Purpose <a name="purpose"></a>
# The U.S. Geological Survey Gap Analysis Project (GAP) created habitat maps for 1590 terrestrial vertebrate species throughout the conterminous US (CONUS), including 219 sub-species. Each species was associated with one or more land cover types represented in the National GAP Land Cover Map (McKerrow et al. 2018, Gergely et al. 2019). The USGS GAP Land Cover Map used vegetation classes based on NatureServe’s Ecological Systems Classification (Comer et al. 2003) and land cover classes described in the National Land Cover Dataset (Homer et al. 2007). These data described vegetation communities at a level of thematic detail useful for ascribing habitat types for species. A crosswalk of that map legend with the nested hierarchy of the US National Vegetation Classification (NVC) permits the assessment of species habitat extents throughtout a broadening thematic vegetation classification.
#
# This notebook specifically outlines using the crosswalk of species habitat associations in the GAP land cover map with NVC macrogroups for linking USDA Forest Inventory and Analysis (FIA) plot level forest composition and structure data.
#
# ## Inputs <a name="inputs"></a>
# The code in this notebook is a first step in combining GAP species habitat association information with FIA plot level data wherein forest structure and composition are tied to NVC macrogroup classes. Since the GAP habitat maps were developed using deductive methods (McKerrow et al. 2018, Gergely et al. 2019) which include landscape attributes other than land cover, it was necessary to identify species whose associations include forest and no other ancillary data such as distance to water or elevation limits.
#
# Data compiled by code in this notebook are assembled in a wildlife habitat relationship database (WHRdb). The WHRdb was queried to compile a list of species associated with at least one forested land cover type (referred to as <b>map units</b> in WHRdb tables) and no ancillary landscape attributes. Modeling parameters were assembled for each species by seasonality - summer (breeding for migratory birds), winter, and year-round (habitat utilized during both summer and winter). Additionally, modeling regions were used to stratify the CONUS into six regions (Northwest, Southwest, Great Plains, Upper Midwest, Southeast, and Northeast). These regions allowed for efficient processing of the species distribution models on smaller, ecologically homogenous extents. Therefore, species habitat associations may occur in multiple seasons and/or across multiple regions. A species model code was developed to maintain unique season/region combinations.
#
# * **U.S. Geological Survey Gap Analysis Project (GAP) Wildlife Habitat Relationship Database** <a name="subinput1"></a>
# Information about access to a given instance of this database is pending. The database is described here: https://www.sciencebase.gov/catalog/item/527d0a83e4b0850ea0518326.
#
# Additionally, this code utilizes an SQL server database that was assembled by intersecting numerous spatial data layers including the PAD-US, species habitat maps, boundary layers such as states, counties, LCCs, ecoregions, etc.
#
# * **U.S. Geological Survey Gap Analysis Project (GAP) Analytical Database** <a name="subinput1"></a>
# These analyses utilize the GAP Analytic database developed by Linda Schueck, Anne Davidson, and Leah Dunn at Boise State University. Information about access to a given instance of this database is pending. The database is described here: https://www.sciencebase.gov/catalog/item/5b736251e4b0f5d5787c61df.
#
# At the time this workflow was developed, both databases were available on a local server. Hence, all code references a local instance of these databases. This code is only replicable given access to a local instance of these databases.
#
# This analysis relies on three major datasets within the analytic database including:
# 1. The detailed land cover dataset: GAP/LANDFIRE National Terrestrial Ecosystems 2011: National Inventory of Vegetation and Land Use  (https://www.sciencebase.gov/catalog/item/5810cd6fe4b0f497e7975237)
# 2. The U.S. National Vegetation Classification Ver 2.0 (http://usnvc.org/explore-classification/)
# 3. A crosswalk between Ecological Systems and the USNVC Types (Embedded in the Attribute file for the National Terrestrials Ecosystems data https://www.sciencebase.gov/catalog/item/5810cd6fe4b0f497e7975237.
#
# ## Outputs <a name="outputs"></a>
# A table and output CSV file with data on species map unit and NVC macrogroup associations organized by season and modeling region. The following columns are included in the table:
# * <b>ScientificName</b> - species scientific name
# * <b>CommonName</b> - species common name
# * <b>SC</b> - species 6-letter code
# * <b>SMC</b> - species 9-charcter model code
# * <b>MUCode</b> - land cover map unit 4-digit code
# * <b>MUName</b> - land cover map unit name
# * <b>Season</b> - species model season
# * <b>Region</b> - species model region
# * <b>Macrogroup</b> - NVC macrogroup name
#
#
# ## Constraints <a name="constraints"></a>
# The Land Cover data attempts to map as accurately as possible the fine vegetative details of the nation’s vegetation. However, there are some limitations to the data that users should keep in mind. The data set uses a 30 meter pixel cell and in most areas a minimum mapping unit of 0.4 ha (1 acre). This means that small patches of vegetation can be missed in the modeling process.  The USNVC is a dynamic content standard, reflecting the state of the science at any point in time; therefore this analysis represents the conservation assessment based on the types that were named and described in the 2017 release of the classification.
#
# ## Dependencies <a name="dependencies"></a>
# These analyses are currently reliant on a local instance of the GAP Wildlife Habitat Relationship database (GAP WHRdb) and the GAP Analytical Database (GAP analytic db).
#
# Code execution dependencies
#
# * **Code Language** <a name="codelanguage"></a>
# This code is written in Python 3.x. Earlier versions may be compatible given slight alterations in syntax and package components.
#   * **Python package requirements** <a name="packagerequirements"></a>
#   The required packages for proper code execution inlclude:
#     - Pandas version 0.2x or above
#     - pyodbc version 4.x or above
#
#
# ## Tests <a name="tests"></a>
# In developing this code the results were compared against a dataset generated through an independent spatial analysis.
#
#
# ## Provenance <a name="provenance"></a>

# %% [markdown]
# ## Code <a name="code"></a>

# %% [markdown]
# #### Import required Python packages

# %%
import pyodbc
import pandas as pd
import pandas.io.sql as psql
#%matplotlib notebook

# %% [markdown]
# #### Accessing the local SQL server instance of the GAP Analytic database

# %%
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#            ++++ Directory Locations ++++
workDir = 'C:/Data/USGS Analyses/Species-Habitat-NVC-Associations/Scripts/'


#############################################################################################
################################### LOCAL FUNCTIONS #########################################
#############################################################################################


## --------------Cursor and Database Connections--------------------

def ConnectToDB(connectionStr):
    '''
    (str) -> cursor, connection

    Provides a cursor within and a connection to the database

    Argument:
    connectionStr -- The SQL Server compatible connection string
        for connecting to a database
    '''
    try:
        con = pyodbc.connect(connectionStr)
    except:
        connectionStr = connectionStr.replace('11.0', '10.0')
        con = pyodbc.connect(connectionStr)

    return con.cursor(), con

## ----------------Database Connection----------------------

def DBConnection(dbname):
    '''
    Returns a cursor and connection within the GAP analytic database.
    '''
    # Database connection parameters
    dbstr = """DRIVER=SQL Server Native Client 11.0;
                    SERVER=CHUCK\SQL2014;
                    UID=;
                    PWD=;
                    TRUSTED_CONNECTION=Yes;
                    DATABASE={0};"""
    dbConStr = dbstr.format(dbname)

    return ConnectToDB(dbConStr)

#############################################################################################
#############################################################################################
#############################################################################################

# %%
## Connect to the Analytic Database
print("+"*45)
print("Connecting to Database ....")
cur, conn = DBConnection('GAP_AnalyticDB')
# Out:
# +++++++++++++++++++++++++++++++++++++++++++++
# Connecting to Database ....

# %% [markdown]
# #### Generating an SQL string to pass to a pandas dataframe

# %%
# Make an SQL that pulls out NVC macrogroups from the Analytic db
sqlGA = """SELECT
            level3,
            nvc_macro AS Macrogroup
        FROM
            GAP_AnalyticDB.dbo.gap_landfire
        WHERE level3 > 0"""

# %% [markdown]
# #### Passing the SQL and getting a pandas dataframe

# %%
# Make a dataframe of the macrogroups with the 4-digit code
print("Creating Dataframe of NVC Macrogroups from Gap Analytic Datbase ....")
dfMacro = psql.read_sql(sqlGA, conn)
# Out:
# Creating Dataframe of NVC Macrogroups from Gap Analytic Datbase ....

# %%
dfMacro
# Out:
#      level3                                         Macrogroup
# 0      9238                                    Caribbean Swamp
# 1      9702                                    Caribbean Swamp
# 2      9305                                    Caribbean Swamp
# 3      9236              Western Atlantic & Caribbean Mangrove
# 4      4132               Caribbean Coastal Lowland Dry Forest
# 5      4135               Caribbean Coastal Lowland Dry Forest
# 6      4134               Caribbean Coastal Lowland Dry Forest
# 7      4145                             Longleaf Pine Woodland
# 8      4505                             Longleaf Pine Woodland
# 9      4506                             Longleaf Pine Woodland
# 10     4536                             Longleaf Pine Woodland
# 11     5602                             Longleaf Pine Woodland
# 12     4508                             Longleaf Pine Woodland
# 13     4509                             Longleaf Pine Woodland
# 14     4503                             Longleaf Pine Woodland
# 15     4502                             Longleaf Pine Woodland
# 16     4321                             Longleaf Pine Woodland
# 17     4210  Southeastern Coastal Plain Evergreen Oak - Mix...
# 18     4212  Southeastern Coastal Plain Evergreen Oak - Mix...
# 19     4136  Southeastern Coastal Plain Evergreen Oak - Mix...
# 20     4102              Southern Mesic Mixed Broadleaf Forest
# 21     4150  Southeastern Coastal Plain Evergreen Oak - Mix...
# 22     4129              Southern Mesic Mixed Broadleaf Forest
# 23     4209              Southern Mesic Mixed Broadleaf Forest
# 24     4153  Southeastern Coastal Plain Evergreen Oak - Mix...
# 25     4130  Southeastern Coastal Plain Evergreen Oak - Mix...
# 26     4146  Southeastern Coastal Plain Evergreen Oak - Mix...
# 27     4137  Southeastern Coastal Plain Evergreen Oak - Mix...
# 28     4204              Southern Mesic Mixed Broadleaf Forest
# 29     4541  Southern & South-Central Oak - Hickory - Pine ...
# ..      ...                                                ...
# 542    3502                                             Barren
# 543    1401                           Woody Horticultural Crop
# 544    1402                 Herbaceous Agricultural Vegetation
# 545    1403                           Pasture & Hay Field Crop
# 546    8404               Introduced & Semi Natural Vegetation
# 547    8407               Introduced & Semi Natural Vegetation
# 548    8408               Introduced & Semi Natural Vegetation
# 549    8402               Introduced & Semi Natural Vegetation
# 550    8406               Introduced & Semi Natural Vegetation
# 551    8401               Introduced & Semi Natural Vegetation
# 552    8501                     Recently Disturbed or Modified
# 553    8101                     Recently Disturbed or Modified
# 554    8108                     Recently Disturbed or Modified
# 555    8107                     Recently Disturbed or Modified
# 556    8106                     Recently Disturbed or Modified
# 557    8301                     Recently Disturbed or Modified
# 558    8303                     Recently Disturbed or Modified
# 559    8304                     Recently Disturbed or Modified
# 560    8302                     Recently Disturbed or Modified
# 561    8103                     Recently Disturbed or Modified
# 562    8102                     Recently Disturbed or Modified
# 563    8502                     Recently Disturbed or Modified
# 564    2104                                         Open Water
# 565    2103                                         Open Water
# 566    2102                                         Open Water
# 567    1301         Quarries, Mines, Gravel Pits and Oil Wells
# 568    1201                                  Developed & Urban
# 569    1202                                  Developed & Urban
# 570    1203                                  Developed & Urban
# 571    1204                                  Developed & Urban
#
# [572 rows x 2 columns]

# %% [markdown]
# #### Delete the cursor and connection to the Analytic database to reuse variables for connection to WHR database

# %%
# Delete the previous db connection variables and reset them for
# connecting to the WHR database
del cur, conn
print('Connecting to Gap WHR Database ....')
cur, conn = DBConnection('GapVert_48_2001')
# Out:
# Connecting to Gap WHR Database ....

# %% [markdown]
# #### Pull out species map unit associations from the WHR for species associated with at least one forested type and no ancillary constraints

# %%
# Make an SQL that gets data for species who have at least one forested map unit
# and have NO ancillary data constraints
sqlWHR = """WITH
-- Build table of species seasonal/regional use of ancillary data
smAnc AS (
	SELECT	i.strUC AS strUC
		  ,	a.strSpeciesModelCode AS strSpeciesModelCode
		  , CAST(ysnHandModel AS int) AS intHandModel
		  , CAST(ysnHydroFW AS int) AS intHydroFW
		  , CAST(ysnHydroOW AS int) AS intHydroOW
		  , CAST(ysnHydroWV AS int) AS intHydroWV
		  , CASE
				WHEN (strSalinity Is Null OR strSalinity = 'All Types') THEN 0
				ELSE 1
			END AS intSalinity
		  , CASE
				WHEN (strStreamVel Is Null OR strStreamVel = 'All Types') THEN 0
				ELSE 1
			END AS intStreamVel
		  , CASE
				WHEN strEdgeType Is Null THEN 0
				ELSE 1
			END AS intEdgeType
		  , CASE
				WHEN strUseForInt Is Null THEN 0
				ELSE 1
			END AS intUseForInt
		  , CAST(cbxContPatch AS int) AS intContPatch
		  ,	CAST(cbxNonCPatch AS int) AS intNonCPatch
		  , CASE
				WHEN intPercentCanopy Is Null THEN 0
				ELSE 1
			END AS intPercentCanopy 
		  , CASE
				WHEN intAuxBuff Is Null THEN 0
				ELSE 1
			END AS intAuxBuff
		  , CASE
				WHEN strAvoid Is Null THEN 0
				ELSE 1
			END AS intAvoid
		  ,	CAST(ysnUrbanExclude AS int) AS intUrbanExclude
		  ,	CAST(ysnUrbanInclude AS int) AS intUrbanInclude
		  , CASE
				WHEN (intElevMin Is Null OR intElevMin < 1) THEN 0
				ELSE 1
			END AS intElevMin
		  , CASE
				WHEN intElevMax Is Null THEN 0
				ELSE 1
			END AS intElevMax

	FROM GapVert_48_2001.dbo.tblModelAncillary a 
		 INNER JOIN GapVert_48_2001.dbo.tblModelInfo i
			ON a.strSpeciesModelCode = i.strSpeciesModelCode
	WHERE	i.ysnIncludeSubModel = 1 
	),

/*
	Identify species ancillary data use across seasonal/regional submodels.
	This sums up how many submodels have at least one ancillary parameter selection.
	Return only species whose submodel ancillary tally total is 0 meaning NO
	submodels use ANY ancillary parameter
*/
NonAncillary AS (
	SELECT
		strUC
	FROM smAnc
	GROUP BY strUC
	HAVING
		SUM ( intHandModel +
			  intHydroFW +
			  intHydroOW +
			  intHydroWV +
			  intSalinity +
			  intStreamVel +
			  intEdgeType +
			  intUseForInt +
			  intContPatch +
			  intNonCPatch +
			  intPercentCanopy +
			  intAuxBuff +
			  intAvoid +
			  intUrbanExclude +
			  intUrbanInclude +
			  intElevMin +
			  intElevMax ) = 0

	),

/*
	Pull out species whose models include at least one map unit selection
	that is a forested map unit.
	NOTE: This criterion is only for primary map units. Secondary map units are ignored
	Also, include only those species for whom there are valid submodels.
*/
ForestSelected AS 
(SELECT
		tblMapUnitDesc.intLSGapMapCode,
		tblMapUnitDesc.strLSGapName,
		tblMapUnitDesc.intForest,
		tblSppMapUnitPres.strSpeciesModelCode,
		tblSppMapUnitPres.ysnPres,
		tblModelInfo.ysnIncludeSubModel,
		tblModelInfo.strUC
FROM 
		tblMapUnitDesc FULL JOIN tblSppMapUnitPres 
		ON tblMapUnitDesc.intLSGapMapCode = tblSppMapUnitPres.intLSGapMapCode
		INNER JOIN tblModelInfo 
		ON tblSppMapUnitPres.strSpeciesModelCode = tblModelInfo.strSpeciesModelCode
WHERE 
		tblMapUnitDesc.intForest = 1 AND 
		tblSppMapUnitPres.ysnPres = 1 AND 
		tblSppMapUnitPres.strSpeciesModelCode Not Like '%m_' AND
		tblModelInfo.ysnIncludeSubModel = 1),

/*
	Pull out the scientific and common names from the taxa table
*/
Taxa AS
(SELECT strUC, strSciName, strComName
FROM tblTaxa)

/*
	Combine the non-ancillary, at least one forested map unit selection, and
	corresponding taxa scientific name and common name sub-queries into final output

*/


SELECT 	Taxa.strSciName AS ScientificName,
		Taxa.strComName AS CommonName,
		Taxa.strUC AS SC,
		strSpeciesModelCode AS SMC,
		ForestSelected.intLSGapMapCode AS MUCode,
		ForestSelected.strLSGapName AS MUName,
		CASE 
			WHEN 
			  SUBSTRING(ForestSelected.strSpeciesModelCode, 8, 1)='y'
			  THEN 'year-round'
			WHEN
			  SUBSTRING(ForestSelected.strSpeciesModelCode, 8, 1)='s'
			  THEN 'summer'
			WHEN
			  SUBSTRING(ForestSelected.strSpeciesModelCode, 8, 1)='w'
			  THEN 'winter'
		END AS Season,
		
		CASE 
			WHEN 
			  SUBSTRING(ForestSelected.strSpeciesModelCode, 9, 1)='1'
			  THEN 'Northwest'
			WHEN
			  SUBSTRING(ForestSelected.strSpeciesModelCode, 9, 1)='2'
			  THEN 'Upper Midwest'
			WHEN
			  SUBSTRING(ForestSelected.strSpeciesModelCode, 9, 1)='3'
			  THEN 'Northeast'
			WHEN
			  SUBSTRING(ForestSelected.strSpeciesModelCode, 9, 1)='4'
			  THEN 'Southwest'
			WHEN
			  SUBSTRING(ForestSelected.strSpeciesModelCode, 9, 1)='5'
			  THEN 'Great Plains'
			WHEN
			  SUBSTRING(ForestSelected.strSpeciesModelCode, 9, 1)='6'
			  THEN 'Southeast'
		END AS Region

FROM
	ForestSelected INNER JOIN NonAncillary
	ON
	ForestSelected.strUC = NonAncillary.strUC
	INNER JOIN Taxa
	ON ForestSelected.strUC = Taxa.strUC"""

# %% [markdown]
# #### Make a dataframe using the above criteria

# %%
# Make a dataframe of the forest/non-ancillary species map unit associations
dfSppMUs = psql.read_sql(sqlWHR, conn)

# %%
dfSppMUs
# Out:
#               ScientificName          CommonName      SC        SMC  MUCode  \
# 0             Storeria victa  Florida Brownsnake  rFLBRx  rFLBRx-y6    9208
# 1             Storeria victa  Florida Brownsnake  rFLBRx  rFLBRx-y6    9703
# 2             Storeria victa  Florida Brownsnake  rFLBRx  rFLBRx-y6    9715
# 3             Storeria victa  Florida Brownsnake  rFLBRx  rFLBRx-y6    9801
# 4             Storeria victa  Florida Brownsnake  rFLBRx  rFLBRx-y6    9838
# 5             Storeria victa  Florida Brownsnake  rFLBRx  rFLBRx-y6    9841
# 6             Storeria victa  Florida Brownsnake  rFLBRx  rFLBRx-y6    9852
# 7         Plethodon aureolus  Tellico Salamander  aTESAx  aTESAx-y6    4127
# 8              Sorex haydeni       Prairie Shrew  mPRSHx  mPRSHx-y5    9818
# 9              Sorex haydeni       Prairie Shrew  mPRSHx  mPRSHx-y2    9818
# 10         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s1    4522
# 11         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s1    4531
# 12         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s1    4611
# 13         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s2    4113
# 14         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s2    4542
# 15         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s3    4113
# 16         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s3    4119
# 17         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s3    4127
# 18         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s3    4133
# 19         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s3    4542
# 20         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s3    4551
# 21         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s4    4528
# 22         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s4    4531
# 23         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s4    4611
# 24         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s5    4528
# 25         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s5    4531
# 26         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s5    4611
# 27         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s6    4113
# 28         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s6    4119
# 29         Catharus guttatus       Hermit Thrush  bHETHx  bHETHx-s6    4127
# ...                      ...                 ...     ...        ...     ...
# 9919  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4122
# 9920  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4125
# 9921  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4128
# 9922  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4151
# 9923  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4205
# 9924  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4308
# 9925  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4311
# 9926  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4331
# 9927  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4334
# 9928  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4337
# 9929  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4403
# 9930  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    4612
# 9931  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    8201
# 9932  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    9240
# 9933  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    9303
# 9934  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    9701
# 9935  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    9804
# 9936  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    9827
# 9937  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    9836
# 9938  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    9844
# 9939  Myotis septentrionalis     Northern Myotis  mNOMYx  mNOMYx-s6    9850
# 9940    Chondestes grammacus        Lark Sparrow  bLASPx  bLASPx-s3    4603
# 9941    Chondestes grammacus        Lark Sparrow  bLASPx  bLASPx-s5    4603
# 9942    Chondestes grammacus        Lark Sparrow  bLASPx  bLASPx-w5    4603
# 9943    Chondestes grammacus        Lark Sparrow  bLASPx  bLASPx-w6    4603
# 9944    Chondestes grammacus        Lark Sparrow  bLASPx  bLASPx-s1    4603
# 9945    Chondestes grammacus        Lark Sparrow  bLASPx  bLASPx-s4    4603
# 9946    Chondestes grammacus        Lark Sparrow  bLASPx  bLASPx-s6    4603
# 9947    Chondestes grammacus        Lark Sparrow  bLASPx  bLASPx-w1    4603
# 9948    Chondestes grammacus        Lark Sparrow  bLASPx  bLASPx-w4    4603
#
#                                                  MUName      Season  \
# 0     Southern Coastal Plain Seepage Swamp and Bayga...  year-round
# 1     Southern Coastal Plain Nonriverine Cypress Dom...  year-round
# 2     Southern Piedmont/Ridge and Valley Upland Depr...  year-round
# 3     Atlantic Coastal Plain Blackwater Stream Flood...  year-round
# 4     Southern Coastal Plain Hydric Hammock         ...  year-round
# 5     Southern Piedmont Small Floodplain and Riparia...  year-round
# 6     Southern Coastal Plain Blackwater River Floodp...  year-round
# 7     Central and Southern Appalachian Montane Oak F...  year-round
# 8     Central Interior and Appalachian Floodplain Sy...  year-round
# 9     Central Interior and Appalachian Floodplain Sy...  year-round
# 10    North Pacific Maritime Dry-Mesic Douglas-fir-W...      summer
# 11    Rocky Mountain Subalpine Dry-Mesic Spruce-Fir ...      summer
# 12    Rocky Mountain Subalpine Mesic Spruce-Fir Fore...      summer
# 13    Laurentian-Acadian Northern Hardwoods Forest  ...      summer
# 14    Laurentian Jack Pine-Red Pine Forest          ...      summer
# 15    Laurentian-Acadian Northern Hardwoods Forest  ...      summer
# 16    Southern Appalachian Northern Hardwood Forest ...      summer
# 17    Central and Southern Appalachian Montane Oak F...      summer
# 18    Atlantic Coastal Plain Dry and Dry-Mesic Oak F...      summer
# 19    Laurentian Jack Pine-Red Pine Forest          ...      summer
# 20    Acadian-Appalachian Montane Spruce-Fir Forest ...      summer
# 21    Southern Rocky Mountain Dry-Mesic Montane Mixe...      summer
# 22    Rocky Mountain Subalpine Dry-Mesic Spruce-Fir ...      summer
# 23    Rocky Mountain Subalpine Mesic Spruce-Fir Fore...      summer
# 24    Southern Rocky Mountain Dry-Mesic Montane Mixe...      summer
# 25    Rocky Mountain Subalpine Dry-Mesic Spruce-Fir ...      summer
# 26    Rocky Mountain Subalpine Mesic Spruce-Fir Fore...      summer
# 27    Laurentian-Acadian Northern Hardwoods Forest  ...      summer
# 28    Southern Appalachian Northern Hardwood Forest ...      summer
# 29    Central and Southern Appalachian Montane Oak F...      summer
# ...                                                 ...         ...
# 9919  Ouachita Montane Oak Forest                   ...      summer
# 9920  Southern and Central Appalachian Oak Forest   ...      summer
# 9921  East Gulf Coastal Plain Northern Loess Bluff F...      summer
# 9922  Lower Mississippi River Dune Woodland and Fore...      summer
# 9923  East Gulf Coastal Plain Northern Mesic Hardwoo...      summer
# 9924  Southern Ridge and Valley Dry Calcareous Fores...      summer
# 9925  Southern Piedmont Dry Oak-Heath Forest - Mixed...      summer
# 9926  Appalachian Hemlock-Hardwood Forest           ...      summer
# 9927  Southern Ridge and Valley Dry Calcareous Fores...      summer
# 9928               Northern Crowley's Ridge Sand Forest      summer
# 9929  Atlantic Coastal Plain Mesic Hardwood and Mixe...      summer
# 9930  Central and Southern Appalachian Spruce-Fir Fo...      summer
# 9931                               Deciduous Plantation      summer
# 9932  Northern Atlantic Coastal Plain Basin Swamp an...      summer
# 9933  Atlantic Coastal Plain Clay-Based Carolina Bay...      summer
# 9934  Lower Mississippi River Bottomland Depressions...      summer
# 9935  East Gulf Coastal Plain Large River Floodplain...      summer
# 9936  Mississippi River Riparian Forest             ...      summer
# 9937  Mississippi River Low Floodplain (Bottomland) ...      summer
# 9938  Red River Large Floodplain Forest             ...      summer
# 9939  South-Central Interior Small Stream and Ripari...      summer
# 9940  Mediterranean California Mesic Mixed Conifer F...      summer
# 9941  Mediterranean California Mesic Mixed Conifer F...      summer
# 9942  Mediterranean California Mesic Mixed Conifer F...      winter
# 9943  Mediterranean California Mesic Mixed Conifer F...      winter
# 9944  Mediterranean California Mesic Mixed Conifer F...      summer
# 9945  Mediterranean California Mesic Mixed Conifer F...      summer
# 9946  Mediterranean California Mesic Mixed Conifer F...      summer
# 9947  Mediterranean California Mesic Mixed Conifer F...      winter
# 9948  Mediterranean California Mesic Mixed Conifer F...      winter
#
#              Region
# 0         Southeast
# 1         Southeast
# 2         Southeast
# 3         Southeast
# 4         Southeast
# 5         Southeast
# 6         Southeast
# 7         Southeast
# 8      Great Plains
# 9     Upper Midwest
# 10        Northwest
# 11        Northwest
# 12        Northwest
# 13    Upper Midwest
# 14    Upper Midwest
# 15        Northeast
# 16        Northeast
# 17        Northeast
# 18        Northeast
# 19        Northeast
# 20        Northeast
# 21        Southwest
# 22        Southwest
# 23        Southwest
# 24     Great Plains
# 25     Great Plains
# 26     Great Plains
# 27        Southeast
# 28        Southeast
# 29        Southeast
# ...             ...
# 9919      Southeast
# 9920      Southeast
# 9921      Southeast
# 9922      Southeast
# 9923      Southeast
# 9924      Southeast
# 9925      Southeast
# 9926      Southeast
# 9927      Southeast
# 9928      Southeast
# 9929      Southeast
# 9930      Southeast
# 9931      Southeast
# 9932      Southeast
# 9933      Southeast
# 9934      Southeast
# 9935      Southeast
# 9936      Southeast
# 9937      Southeast
# 9938      Southeast
# 9939      Southeast
# 9940      Northeast
# 9941   Great Plains
# 9942   Great Plains
# 9943      Southeast
# 9944      Northwest
# 9945      Southwest
# 9946      Southeast
# 9947      Northwest
# 9948      Southwest
#
# [9949 rows x 8 columns]

# %% [markdown]
# ### Merge the two dataframes derived from the Analytic and WHR databases to show map units and their associated macrogroups

# %%
# Merge the dataframes from the WHR and Analytc dbs using the columns
# that have map unit 4-digit codes: MUCode and level3 respectively
dfSppMUs_Macro = pd.merge(left=dfSppMUs, right=dfMacro, how='inner',
                      left_on='MUCode', right_on='level3')

# %%
dfSppMUs_Macro=dfSppMUs_Macro.sort_values(by=['SMC'])
dfSppMUs_Macro
# Out:
#                 ScientificName                     CommonName      SC  \
# 9529          Aneides lugubris            Arboreal Salamander  aARSAx
# 9530          Aneides lugubris            Arboreal Salamander  aARSAx
# 8835      Plethodon caddoensis      Caddo Mountain Salamander  aCMSAx
# 3737      Plethodon caddoensis      Caddo Mountain Salamander  aCMSAx
# 3911      Plethodon caddoensis      Caddo Mountain Salamander  aCMSAx
# 5159        Plethodon kentucki  Cumberland Plateau Salamander  aCPSAx
# 1618        Plethodon kentucki  Cumberland Plateau Salamander  aCPSAx
# 9491   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 967    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 6506   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4782   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 9623   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 6463   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 9552   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 2097   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4222   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 9841   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 7540   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 6088   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 7585   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 416    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 2370   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 1963   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 8403   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 920    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 7199   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 9692   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4364   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 6150   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4223   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# ...                        ...                            ...     ...
# 6723  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 1273  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 6335  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 3609  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 4531  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 4041  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 3880  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 6991  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 5287  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 8620  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 7379  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 8565  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 8827  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 2092  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 4650  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 6570  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 5088  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 6886  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 6859  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 4590  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 4764  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 4700  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 8755  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 3141  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 1143      Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 4215      Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 9680      Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 6224      Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 4094     Gonatodes albogularis            Yellow-headed Gecko  rYHGEx
# 7743     Gonatodes albogularis            Yellow-headed Gecko  rYHGEx
#
#             SMC  MUCode                                             MUName  \
# 9529  aARSAx-y1    4317  Mediterranean California Lower Montane Black O...
# 9530  aARSAx-y4    4317  Mediterranean California Lower Montane Black O...
# 8835  aCMSAx-y6    4122  Ouachita Montane Oak Forest                   ...
# 3737  aCMSAx-y6    4115  Ozark-Ouachita Dry-Mesic Oak Forest           ...
# 3911  aCMSAx-y6    4207  Ozark-Ouachita Mesic Hardwood Forest          ...
# 5159  aCPSAx-y6    4401  Southern and Central Appalachian Cove Forest  ...
# 1618  aCPSAx-y6    4402  South-Central Interior Mesophytic Forest      ...
# 9491  aCSLSx-y1    4606  North Pacific Maritime Mesic-Wet Douglas-fir-W...
# 967   aCSLSx-y1    4545  California Coastal Closed-Cone Conifer Forest ...
# 6506  aCSLSx-y1    4607  North Pacific Mesic Western Hemlock-Silver Fir...
# 4782  aCSLSx-y1    4613  North Pacific Hypermaritime Western Red-cedar-...
# 9623  aCSLSx-y1    4320  Mediterranean California Mixed Evergreen Fores...
# 6463  aCSLSx-y1    4547  North Pacific Dry-Mesic Silver Fir-Western Hem...
# 9552  aCSLSx-y1    4317  Mediterranean California Lower Montane Black O...
# 2097  aCSLSx-y1    8401               Introduced Upland Vegetation - Treed
# 4222  aCSLSx-y1    4519  Mediterranean California Dry-Mesic Mixed Conif...
# 9841  aCSLSx-y1    4148  North Pacific Broadleaf Landslide Forest and S...
# 7540  aCSLSx-y1    4601  California Coastal Redwood Forest             ...
# 6088  aCSLSx-y1    4338  North Pacific Lowland Mixed Hardwood-Conifer F...
# 7585  aCSLSx-y1    4604  North Pacific Hypermaritime Sitka Spruce Fores...
# 416   aCSLSx-y1    4522  North Pacific Maritime Dry-Mesic Douglas-fir-W...
# 2370  aCSLSx-y1    8203                            Managed Tree Plantation
# 1963  aCSLSx-y1    8106  Harvested Forest - Northwestern Conifer Regene...
# 8403  aCSLSx-y1    8201                               Deciduous Plantation
# 920   aCSLSx-y1    4319  North Pacific Dry Douglas-fir-(Madrone) Forest...
# 7199  aCSLSx-y1    8202               Evergreen Plantation or Managed Pine
# 9692  aCSLSx-y1    4603  Mediterranean California Mesic Mixed Conifer F...
# 4364  aCSLSx-y1    4533  Sierra Nevada Subalpine Lodgepole Pine Forest ...
# 6150  aCSLSx-y1    9811  North Pacific Lowland Riparian Forest and Shru...
# 4223  aCSLSx-y4    4519  Mediterranean California Dry-Mesic Mixed Conif...
# ...         ...     ...                                                ...
# 6723  rYBKIx-y5    4137  West Gulf Coastal Plain Chenier and Upper Texa...
# 1273  rYBKIx-y5    4136  Central and South Texas Coastal Fringe Forest ...
# 6335  rYBKIx-y5    4312  Western Great Plains Dry Bur Oak Forest and Wo...
# 3609  rYBKIx-y5    4553  Atlantic Coastal Plain Fall-line Sandhills Lon...
# 4531  rYBKIx-y5    4121  North-Central Interior Dry Oak Forest and Wood...
# 4041  rYBKIx-y5    4321  West Gulf Coastal Plain Upland Longleaf Pine F...
# 3880  rYBKIx-y5    4155  Edwards Plateau Dry-Mesic Slope Forest and Woo...
# 6991  rYBKIx-y6    4504  Atlantic Coastal Plain Fall-Line Sandhills Lon...
# 5287  rYBKIx-y6    4538  Southern Appalachian Low Mountain Pine Forest ...
# 8620  rYBKIx-y6    4311  Southern Piedmont Dry Oak-Heath Forest - Mixed...
# 7379  rYBKIx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
# 8565  rYBKIx-y6    4308  Southern Ridge and Valley Dry Calcareous Fores...
# 8827  rYBKIx-y6    4105  East Gulf Coastal Plain Northern Loess Plain O...
# 2092  rYBKIx-y6    4305  Southern Piedmont Dry Oak-(Pine) Forest - Lobl...
# 4650  rYBKIx-y6    4310  Southern Piedmont Dry Oak-(Pine) Forest - Mixe...
# 6570  rYBKIx-y6    4106  Northeastern Interior Dry Oak Forest - Mixed M...
# 5088  rYBKIx-y6    4309  East Gulf Coastal Plain Interior Shortleaf Pin...
# 6886  rYBKIx-y6    4306  East Gulf Coastal Plain Northern Dry Upland Ha...
# 6859  rYBKIx-y6    4303  East Gulf Coastal Plain Black Belt Calcareous ...
# 4590  rYBKIx-y6    4304  Northeastern Interior Dry Oak Forest - Virgini...
# 4764  rYBKIx-y6    4307  Allegheny-Cumberland Dry Oak Forest and Woodla...
# 4700  rYBKIx-y6    4507  East Gulf Coastal Plain Interior Upland Longle...
# 8755  rYBKIx-y6    4403  Atlantic Coastal Plain Mesic Hardwood and Mixe...
# 3141  rYBKIx-y6    4330  Central Appalachian Oak and Pine Forest       ...
# 1143  rYBSLx-y4    4316  Madrean Upper Montane Conifer-Oak Forest and W...
# 4215  rYBSLx-y4    4519  Mediterranean California Dry-Mesic Mixed Conif...
# 9680  rYBSLx-y4    4603  Mediterranean California Mesic Mixed Conifer F...
# 6224  rYBSLx-y4    4315  Madrean Pine-Oak Forest and Woodland          ...
# 4094  rYHGEx-y6    4132  South Florida Hardwood Hammock                ...
# 7743  rYHGEx-y6    9702  South Florida Cypress Dome                    ...
#
#           Season        Region  level3  \
# 9529  year-round     Northwest    4317
# 9530  year-round     Southwest    4317
# 8835  year-round     Southeast    4122
# 3737  year-round     Southeast    4115
# 3911  year-round     Southeast    4207
# 5159  year-round     Southeast    4401
# 1618  year-round     Southeast    4402
# 9491  year-round     Northwest    4606
# 967   year-round     Northwest    4545
# 6506  year-round     Northwest    4607
# 4782  year-round     Northwest    4613
# 9623  year-round     Northwest    4320
# 6463  year-round     Northwest    4547
# 9552  year-round     Northwest    4317
# 2097  year-round     Northwest    8401
# 4222  year-round     Northwest    4519
# 9841  year-round     Northwest    4148
# 7540  year-round     Northwest    4601
# 6088  year-round     Northwest    4338
# 7585  year-round     Northwest    4604
# 416   year-round     Northwest    4522
# 2370  year-round     Northwest    8203
# 1963  year-round     Northwest    8106
# 8403  year-round     Northwest    8201
# 920   year-round     Northwest    4319
# 7199  year-round     Northwest    8202
# 9692  year-round     Northwest    4603
# 4364  year-round     Northwest    4533
# 6150  year-round     Northwest    9811
# 4223  year-round     Southwest    4519
# ...          ...           ...     ...
# 6723  year-round  Great Plains    4137
# 1273  year-round  Great Plains    4136
# 6335  year-round  Great Plains    4312
# 3609  year-round  Great Plains    4553
# 4531  year-round  Great Plains    4121
# 4041  year-round  Great Plains    4321
# 3880  year-round  Great Plains    4155
# 6991  year-round     Southeast    4504
# 5287  year-round     Southeast    4538
# 8620  year-round     Southeast    4311
# 7379  year-round     Southeast    9911
# 8565  year-round     Southeast    4308
# 8827  year-round     Southeast    4105
# 2092  year-round     Southeast    4305
# 4650  year-round     Southeast    4310
# 6570  year-round     Southeast    4106
# 5088  year-round     Southeast    4309
# 6886  year-round     Southeast    4306
# 6859  year-round     Southeast    4303
# 4590  year-round     Southeast    4304
# 4764  year-round     Southeast    4307
# 4700  year-round     Southeast    4507
# 8755  year-round     Southeast    4403
# 3141  year-round     Southeast    4330
# 1143  year-round     Southwest    4316
# 4215  year-round     Southwest    4519
# 9680  year-round     Southwest    4603
# 6224  year-round     Southwest    4315
# 4094  year-round     Southeast    4132
# 7743  year-round     Southeast    9702
#
#                                              Macrogroup
# 9529                      Californian Forest & Woodland
# 9530                      Californian Forest & Woodland
# 8835  Southern & South-Central Oak - Hickory - Pine ...
# 3737  Southern & South-Central Oak - Hickory - Pine ...
# 3911                       Central Midwest Mesic Forest
# 5159  Appalachian-Central Interior-Northeastern Mesi...
# 1618  Appalachian-Central Interior-Northeastern Mesi...
# 9491              Vancouverian Lowland & Montane Forest
# 967                       Californian Forest & Woodland
# 6506              Vancouverian Lowland & Montane Forest
# 4782              Vancouverian Lowland & Montane Forest
# 9623                      Californian Forest & Woodland
# 6463              Vancouverian Lowland & Montane Forest
# 9552                      Californian Forest & Woodland
# 2097               Introduced & Semi Natural Vegetation
# 4222      Southern Vancouverian Montane-Foothill Forest
# 9841              Vancouverian Lowland & Montane Forest
# 7540              Vancouverian Lowland & Montane Forest
# 6088              Vancouverian Lowland & Montane Forest
# 7585              Vancouverian Lowland & Montane Forest
# 416               Vancouverian Lowland & Montane Forest
# 2370              Eastern North American Ruderal Forest
# 1963                     Recently Disturbed or Modified
# 8403         Southeastern North American Ruderal Forest
# 920           Southern Vancouverian Dry Foothill Forest
# 7199         Southeastern North American Ruderal Forest
# 9692      Southern Vancouverian Montane-Foothill Forest
# 4364                      Vancouverian Subalpine Forest
# 6150  Vancouverian Lowland Marsh, Wet Meadow & Shrub...
# 4223      Southern Vancouverian Montane-Foothill Forest
# ...                                                 ...
# 6723  Southeastern Coastal Plain Evergreen Oak - Mix...
# 1273  Southeastern Coastal Plain Evergreen Oak - Mix...
# 6335                     Great Plains Forest & Woodland
# 3609                             Longleaf Pine Woodland
# 4531     Central Midwest Oak Forest, Woodland & Savanna
# 4041                             Longleaf Pine Woodland
# 3880                  Edwards Plateau Forest & Woodland
# 6991         Southeastern North American Ruderal Forest
# 5287  Southern & South-Central Oak - Hickory - Pine ...
# 8620  Southern & South-Central Oak - Hickory - Pine ...
# 7379     Southern Coastal Plain Basin Swamp & Flatwoods
# 8565  Appalachian-Northeastern Oak - Hardwood - Pine...
# 8827  Southern & South-Central Oak - Hickory - Pine ...
# 2092         Southeastern North American Ruderal Forest
# 4650  Southern & South-Central Oak - Hickory - Pine ...
# 6570  Appalachian-Northeastern Oak - Hardwood - Pine...
# 5088  Southern & South-Central Oak - Hickory - Pine ...
# 6886         Southeastern North American Ruderal Forest
# 6859  Southern & South-Central Oak - Hickory - Pine ...
# 4590  Appalachian-Northeastern Oak - Hardwood - Pine...
# 4764  Appalachian-Northeastern Oak - Hardwood - Pine...
# 4700         Southeastern North American Ruderal Forest
# 8755              Southern Mesic Mixed Broadleaf Forest
# 3141  Appalachian-Northeastern Oak - Hardwood - Pine...
# 1143                  Madrean Montane Forest & Woodland
# 4215      Southern Vancouverian Montane-Foothill Forest
# 9680      Southern Vancouverian Montane-Foothill Forest
# 6224                  Madrean Montane Forest & Woodland
# 4094               Caribbean Coastal Lowland Dry Forest
# 7743                                    Caribbean Swamp
#
# [9864 rows x 10 columns]

# %% [markdown]
# ### Export the data to a CSV file

# %%
# Export to CSV file
dfSppMUs_Macro.to_csv(workDir + "Species-Habitat-Macrogroups.csv")

# %% [markdown]
# ## Citations <a name="citations"></a>
# Comer, P.J., Faber-Langendoen D., Evans, R., Gawler, S.C., Josse, C., Kittel, G., Menard, S., Pyne, M., Reid, M., Schulz, K., Snow, K., and Teague, J., 2003, Ecological systems of the United States—A working classification of U.S. terrestrial systems: Arlington, NatureServe. [Also available at http://www.natureserve.org/biodiversity-science/publications/ecological-systems-united-states.
#
# Gergely, K.J., Boykin, K.G., McKerrow, A.J., Rubino, M.J., Tarr, N.M., and Williams, S.G., 2019, Gap Analysis Project (GAP) terrestrial vertebrate species richness maps for the conterminous U.S.: U.S. Geological Survey Scientific Investigations Report 2019–5034, 99 p., https://doi.org/10.3133/sir20195034.
#
# Homer, C.J., Dewitz, J., Fry, M., Coan, N., Hossain, C., Larson, N., Herold, A., McKerrow, J.N., VanDriel, J.N., and Wickham, J., 2007, Completion of the 2001 National Land Cover Database for the Conterminous United States: Photogrammetric Engineering and Remote Sensing, v. 73, issue 4, p. 337–341, accessed July 30, 2018, at https://www.researchgate.net/profile/Collin_Homer/publication/237239863_Completion_of_the_2001_National_Land_Cover_Database_for_the_Conterminous_United_States/links/0046352ab204d93a3e000000.pdf.
#
# McKerrow, A.J., Tarr, N.M., Rubino, M.J., and Williams, S.G., 2018, Patterns of species richness hotspots and estimates of their protection are sensitive to spatial resolution: Diversity and Distributions, v. 24, issue 10, p. 1464–1477, accessed July 30, 2018, at https://doi.org/10.1111/ddi.12779.
#
# U.S. Geological Survey Gap Analysis Program, 20160513, GAP/LANDFIRE National Terrestrial Ecosystems 2011: U.S. Geological Survey, https://doi.org/10.5066/F7ZS2TM0.
#
# USNVC [United States National Vegetation Classification]. 2017. United States National Vegetation Classification Database, V2.01. Federal Geographic Data Committee, Vegetation Subcommittee, Washington DC. [usnvc.org/explore-classification/] (accessed 30 March 2017).
